# %%
# Import packages
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

# %%
# Header to set the requests as a browser requests
headers = {
    'authority': 'www.amazon.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9,bn;q=0.8',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'
}

# %%
# URL of The amazon Review page
reviews_url = 'https://www.amazon.com/Legendary-Whitetails-Journeyman-Jacket-Tarmac/product-reviews/B013KW38RQ/'

# %%
# Define Page No
len_page = 4

# %%
# Extra Data as Html object from amazon Review page
def reviewsHtml(url, len_page):
    
    # Empty List define to store all pages html data
    soups = []
    
    # Loop for gather all 3000 reviews from all pages via range
    for page_no in range(1, len_page + 1):
        
        # parameter set as page no to the requests body
        params = {
            'ie': 'UTF8',
            'reviewerType': 'all_reviews',
            'filterByStar': 'critical',
            'pageNumber': page_no,
        }
        
        # Request make for each page
        response = requests.get(url, headers=headers)
        
        # Save Html object by using BeautifulSoup4 and lxml parser
        soup = BeautifulSoup(response.text, 'lxml')
        
        # Add single Html page data in master soups list
        soups.append(soup)
        
    return soups

# %%
# Grab Reviews name, description, date, stars, title from HTML
def getReviews(html_data):

    # Create Empty list to Hold all data
    data_dicts = []
    
    # Select all Reviews BOX html using css selector
    boxes = html_data.select('div[data-hook="review"]')
    
    # Iterate all Reviews BOX 
    for box in boxes:
        
        # Select Name using css selector and cleaning text using strip()
        # If Value is empty define value with 'N/A' for all.
        try:
            name = box.select_one('[class="a-profile-name"]').text.strip()
        except Exception as e:
            name = 'N/A'

        try:
            stars = box.select_one('[data-hook="review-star-rating"]').text.strip().split(' out')[0]
        except Exception as e:
            stars = 'N/A'   

        try:
            title = box.select_one('[data-hook="review-title"]').text.strip().split('\n')[-1]
        except Exception as e:
            title = 'N/A'

        try:
            # Convert date str to dd/mm/yyy format
            datetime_str = box.select_one('[data-hook="review-date"]').text.strip().split(' on ')[-1]
            date = datetime.strptime(datetime_str, '%B %d, %Y').strftime("%d/%m/%Y")
        except Exception as e:
            date = 'N/A'

        try:
            description = box.select_one('[data-hook="review-body"]').text.strip()
        except Exception as e:
            description = 'N/A'

        # create Dictionary with al review data 
        data_dict = {
            'Name' : name,
            'Stars' : stars,
            'Title' : title,
            'Date' : date,
            'Description' : description
        }

        # Add Dictionary in master empty List
        data_dicts.append(data_dict)
    
    return data_dicts

# %% [markdown]
# ### <font color="red">Data Process</font>

# %%
# Grab all HTML
html_datas = reviewsHtml(reviews_url, len_page)

# %%
# Empty List to Hold all reviews data
reviews = []

# %%
# Iterate all Html page 
for html_data in html_datas:
    
    # Grab review data
    review = getReviews(html_data)
    
    # add review data in reviews empty list
    reviews += review

# %%
# Create a dataframe with reviews Data
df_reviews = pd.DataFrame(reviews)

# %%
df_reviews
# Out:
#                   Name Stars  \
# 0   Melissa Sugar-Gold   5.0
# 1                 Kyle   5.0
# 2                 Nick   5.0
# 3                 Jeff   4.0
# 4              #1NDfan   5.0
# 5               Bartek   5.0
# 6                 Loki   3.0
# 7           Review man   5.0
# 8                Scott   4.0
# 9                 Aldo   4.0
# 10  Melissa Sugar-Gold   5.0
# 11                Kyle   5.0
# 12                Nick   5.0
# 13                Jeff   4.0
# 14             #1NDfan   5.0
# 15              Bartek   5.0
# 16                Loki   3.0
# 17          Review man   5.0
# 18               Scott   4.0
# 19                Aldo   4.0
# 20  Melissa Sugar-Gold   5.0
# 21                Kyle   5.0
# 22                Nick   5.0
# 23                Jeff   4.0
# 24             #1NDfan   5.0
# 25              Bartek   5.0
# 26                Loki   3.0
# 27          Review man   5.0
# 28               Scott   4.0
# 29                Aldo   4.0
# 30  Melissa Sugar-Gold   5.0
# 31                Kyle   5.0
# 32                Nick   5.0
# 33                Jeff   4.0
# 34             #1NDfan   5.0
# 35              Bartek   5.0
# 36                Loki   3.0
# 37          Review man   5.0
# 38               Scott   4.0
# 39                Aldo   4.0
#
#                                                 Title        Date  \
# 0   Durable, Attractive, Multi-Functional Shirt/Ja...  01/08/2022
# 1            Very comfortable and looks as advertised  09/07/2024
# 2                       Bought twice, would buy again  24/02/2024
# 3   Rugged, good look and nice fit, but should you...  02/10/2018
# 4                                Functional & durable  28/04/2024
# 5   Rugged Comfort Meets Style: The Ultimate Shirt...  19/03/2024
# 6                             Looks aren't everything  16/04/2024
# 7                                         Looks great  27/08/2024
# 8                         More Polyester than cotton?  02/09/2024
# 9                                  Nice light jacket.  13/08/2024
# 10  Durable, Attractive, Multi-Functional Shirt/Ja...  01/08/2022
# 11           Very comfortable and looks as advertised  09/07/2024
# 12                      Bought twice, would buy again  24/02/2024
# 13  Rugged, good look and nice fit, but should you...  02/10/2018
# 14                               Functional & durable  28/04/2024
# 15  Rugged Comfort Meets Style: The Ultimate Shirt...  19/03/2024
# 16                            Looks aren't everything  16/04/2024
# 17                                        Looks great  27/08/2024
# 18                        More Polyester than cotton?  02/09/2024
# 19                                 Nice light jacket.  13/08/2024
# 20  Durable, Attractive, Multi-Functional Shirt/Ja...  01/08/2022
# 21           Very comfortable and looks as advertised  09/07/2024
# 22                      Bought twice, would buy again  24/02/2024
# 23  Rugged, good look and nice fit, but should you...  02/10/2018
# 24                               Functional & durable  28/04/2024
# 25  Rugged Comfort Meets Style: The Ultimate Shirt...  19/03/2024
# 26                            Looks aren't everything  16/04/2024
# 27                                        Looks great  27/08/2024
# 28                        More Polyester than cotton?  02/09/2024
# 29                                 Nice light jacket.  13/08/2024
# 30  Durable, Attractive, Multi-Functional Shirt/Ja...  01/08/2022
# 31           Very comfortable and looks as advertised  09/07/2024
# 32                      Bought twice, would buy again  24/02/2024
# 33  Rugged, good look and nice fit, but should you...  02/10/2018
# 34                               Functional & durable  28/04/2024
# 35  Rugged Comfort Meets Style: The Ultimate Shirt...  19/03/2024
# 36                            Looks aren't everything  16/04/2024
# 37                                        Looks great  27/08/2024
# 38                        More Polyester than cotton?  02/09/2024
# 39                                 Nice light jacket.  13/08/2024
#
#                                           Description
# 0   I purchased various Legendary Whitetails Men's...
# 1   Fits well, made from comfortable and durable m...
# 2   I bought this jacket first five years ago and ...
# 3   The short answer to if you should go down from...
# 4   Bought this for my farmer husband (Christmas 2...
# 5   The Legendary Whitetails Journeyman Shirt Jack...
# 6   Pros: comfortable, stylishCons: when I first p...
# 7   Fits great, comfortable and stylish.Lots of co...
# 8   Just ordered this and very impressed with the ...
# 9   Looks great. I wasn’t expecting to be a nice p...
# 10  I purchased various Legendary Whitetails Men's...
# 11  Fits well, made from comfortable and durable m...
# 12  I bought this jacket first five years ago and ...
# 13  The short answer to if you should go down from...
# 14  Bought this for my farmer husband (Christmas 2...
# 15  The Legendary Whitetails Journeyman Shirt Jack...
# 16  Pros: comfortable, stylishCons: when I first p...
# 17  Fits great, comfortable and stylish.Lots of co...
# 18  Just ordered this and very impressed with the ...
# 19  Looks great. I wasn’t expecting to be a nice p...
# 20  I purchased various Legendary Whitetails Men's...
# 21  Fits well, made from comfortable and durable m...
# 22  I bought this jacket first five years ago and ...
# 23  The short answer to if you should go down from...
# 24  Bought this for my farmer husband (Christmas 2...
# 25  The Legendary Whitetails Journeyman Shirt Jack...
# 26  Pros: comfortable, stylishCons: when I first p...
# 27  Fits great, comfortable and stylish.Lots of co...
# 28  Just ordered this and very impressed with the ...
# 29  Looks great. I wasn’t expecting to be a nice p...
# 30  I purchased various Legendary Whitetails Men's...
# 31  Fits well, made from comfortable and durable m...
# 32  I bought this jacket first five years ago and ...
# 33  The short answer to if you should go down from...
# 34  Bought this for my farmer husband (Christmas 2...
# 35  The Legendary Whitetails Journeyman Shirt Jack...
# 36  Pros: comfortable, stylishCons: when I first p...
# 37  Fits great, comfortable and stylish.Lots of co...
# 38  Just ordered this and very impressed with the ...
# 39  Looks great. I wasn’t expecting to be a nice p...

# %%
# Save data
df_reviews.to_csv('reviews.csv', index=False)

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer


# Initialize VADER sentiment analyzer
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

# Define a function to calculate sentiment scores
def analyze_sentiment(text):
    sentiment_scores = sid.polarity_scores(text)
    return sentiment_scores['compound']

# Apply sentiment analysis to the review column
df_reviews['sentiment_score'] = df_reviews['Description'].apply(analyze_sentiment)

# Classify sentiment based on compound score
df_reviews['sentiment'] = df_reviews['sentiment_score'].apply(lambda score: 'positive' if score > 0 else 'negative' if score < 0 else 'neutral')

# Display the DataFrame with sentiment analysis
df_reviews.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\rites\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                  Name Stars  \
# 0  Melissa Sugar-Gold   5.0
# 1                Kyle   5.0
# 2                Nick   5.0
# 3                Jeff   4.0
# 4             #1NDfan   5.0
#
#                                                Title        Date  \
# 0  Durable, Attractive, Multi-Functional Shirt/Ja...  01/08/2022
# 1           Very comfortable and looks as advertised  09/07/2024
# 2                      Bought twice, would buy again  24/02/2024
# 3  Rugged, good look and nice fit, but should you...  02/10/2018
# 4                               Functional & durable  28/04/2024
#
#                                          Description  sentiment_score  \
# 0  I purchased various Legendary Whitetails Men's...           0.9940
# 1  Fits well, made from comfortable and durable m...           0.8860
# 2  I bought this jacket first five years ago and ...           0.9941
# 3  The short answer to if you should go down from...           0.9942
# 4  Bought this for my farmer husband (Christmas 2...           0.8922
#
#   sentiment
# 0  positive
# 1  positive
# 2  positive
# 3  positive
# 4  positive

# %%
import openpyxl

# Export the DataFrame to an Excel file
output_file_path = 'review_sentiments.xlsx'
df_reviews.to_excel(output_file_path, index=False)

print(f"Sentiment analysis results saved to {output_file_path}")
# Out:
# Sentiment analysis results saved to review_sentiments.xlsx
